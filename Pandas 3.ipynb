# %%
import pandas as pd

# Custom indexes

# %%
people = { 
    'first_name': ['Syed', 'Mohd', 'Syed'],
    'last_name': ['Dayim', 'Alim', 'Orhan'],
    'email': ['syeddayim@gmail.com', 'modhalim@gmail.com', 'syedorhan@gmail.com']
}
df = pd.DataFrame(people)
df
# Out:
#   first_name last_name                email
# 0       Syed     Dayim  syeddayim@gmail.com
# 1       Mohd      Alim   modhalim@gmail.com
# 2       Syed     Orhan  syedorhan@gmail.com

# %%
df.set_index('email', inplace=True)
df
# Out:
#                     first_name last_name
# email
# syeddayim@gmail.com       Syed     Dayim
# modhalim@gmail.com        Mohd      Alim
# syedorhan@gmail.com       Syed     Orhan

# %%
df.reset_index(inplace=True)
df
# Out:
#    index                email first_name last_name
# 0      0  syeddayim@gmail.com       Syed     Dayim
# 1      1   modhalim@gmail.com       Mohd      Alim
# 2      2  syedorhan@gmail.com       Syed     Orhan

# %%
mydf = pd.read_csv('data/survey_results_public.csv')
schema_df = pd.read_csv('data/survey_results_schema.csv')

pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)
mydf.set_index('MainBranch', inplace=True)
mydf.head()
# schema_df
# Out:
#                                                     Respondent Hobbyist  \
# MainBranch
# I am a student who is learning to code                       1      Yes
# I am a student who is learning to code                       2       No
# I am not primarily a developer, but I write cod...           3      Yes
# I am a developer by profession                               4       No
# I am a developer by profession                               5      Yes
#
#                                                                    OpenSourcer  \
# MainBranch
# I am a student who is learning to code                                   Never
# I am a student who is learning to code                 Less than once per year
# I am not primarily a developer, but I write cod...                       Never
# I am a developer by profession                                           Never
# I am a developer by profession                      Once a month or more often
#
# ...

# %%
schema_df.set_index('Column', inplace=True)
schema_df
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# ...

# %%
schema_df.loc['Hobbyist', 'QuestionText']
schema_df.loc['MgrIdiot', 'QuestionText']
# Out:
# 'How confident are you that your manager knows what they’re doing?'

# %%
schema_df.sort_index()
schema_df.loc['BlockchainIs', 'QuestionText']
# Out:
# 'Blockchain / cryptocurrency technology is primarily:'
